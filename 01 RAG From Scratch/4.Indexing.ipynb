# %% [markdown]
# # 1. Chunk Optimization
# Semantic Spliter : Optimizing chunk size for embeddings
# Could be based on the followings :
# * Charecters
# * Sections
# * Semantics
# * Delimiters

# %% [markdown]
# # 2. Multi - Represensentation Indexing
# Taking the collection of parent documents -> Converting them into summary -> Indexing that
